# %% [raw]
# ## leet code 189. Rotate Array

# %%
def solution(arr,k):
    n=len(arr)
    for i in range(k):
        store= arr[i]# we are storing the value  
        arr[i]= arr[n-1]
        
        for j in range(1,n):
            store_2=arr[j]
            print(f'{arr[j]} this  is the array number at {j} index') 
            arr[j]=store
            print(f',  ths is updated numer {arr[j]} pudated using stored value {store}') 
            #update store 2 
            
            store=store_2 
            print(f'we are now updataing store to store_2 which is now {store} ')

a= [1,2,3,4,5]
solution(a,2)
a
# Out:
# 2 this  is the array number at 1 index
# ,  ths is updated numer 1 pudated using stored value 1
# we are now updataing store to store_2 which is now 2
# 3 this  is the array number at 2 index
# ,  ths is updated numer 2 pudated using stored value 2
# we are now updataing store to store_2 which is now 3
# 4 this  is the array number at 3 index
# ,  ths is updated numer 3 pudated using stored value 3
# we are now updataing store to store_2 which is now 4
# 5 this  is the array number at 4 index
# ,  ths is updated numer 4 pudated using stored value 4
# we are now updataing store to store_2 which is now 5
# 4 this  is the array number at 1 index
# ,  ths is updated numer 1 pudated using stored value 1
# we are now updataing store to store_2 which is now 4
# 2 this  is the array number at 2 index
# ,  ths is updated numer 4 pudated using stored value 4
# we are now updataing store to store_2 which is now 2
# 3 this  is the array number at 3 index
# ...

# %%
def rotate(arr, k):
    
    store_value = arr[0]
    for i in range(0,k):
        arr[i]=arr[i+k]
        # upadet the orginal index two,
        arr[i+k]=store_value
        print(f'{arr}, {i}')

        
a= [1,2,3,4,5]
rotate(a,1)
# Out:
# [2, 1, 3, 4, 5], 0

# %%
def rotate(arr, k):
    n = len(arr)
    k = k % n  
    arr[:] = arr[-k:] + arr[:-k]
    return arr
# Out:
# [4, 5, 1, 2, 3]

# %%
a= [1,2,3,4,5,6,7,8]
a[:]
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
a[-2:]
# Out:
# [7, 8]

# %%
a[:-2]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a[:]== a[:-2]+a[-2:]
# Out:
# True

# %%
## mediuam f two soted array 

## logi 
nums1 = [1,3] # here it sorted rigth. 
nums2 = [2]


def merge( nums1, nums2):
    sorted_arr = []
    i = j = 0

    # Compare elements from both lists and pick the smaller one
    while i < len(nums1) and j < len(nums2):
        if nums1[i] < nums2[j]:
            sorted_arr.append(nums1[i])
            i += 1
        else:
            sorted_arr.append(nums2[j])
            j += 1

    # Append any leftover elements
    sorted_arr.extend(nums1[i:])
    sorted_arr.extend(nums2[j:])
    
    return sorted_arr
def median(sorted_arr):
    n=len(sorted_arr)
    mid= (len(sorted_arr)//2)
    if n%2 == 0:
        return sorted_arr[(mid-1)]
    else:
        sum1 = sorted_arr[mid-1]+sorted_arr[mid]
        median= sum1//2
        return median
# Out:
#   Cell In[38], line 9
#     sorted_arr = []
#     ^
# IndentationError: expected an indented block after function definition on line 8

# %%
class Solution:
    def findMedianSortedArrays(self, nums1, nums2):
        # 1. Merge the two sorted arrays (Your logic)
        merged = self._merge(nums1, nums2)
        
        # 2. Calculate the median
        n = len(merged)
        mid = n // 2
        
        if n % 2 != 0:
            # Odd: return the middle element
            return float(merged[mid])
        else:
            # Even: return average of the two middle elements
            return (merged[mid - 1] + merged[mid]) / 2.0

    def _merge(self, nums1, nums2):
        sorted_arr = []
        i = j = 0
        while i < len(nums1) and j < len(nums2):
            if nums1[i] < nums2[j]:
                sorted_arr.append(nums1[i])
                i += 1
            else:
                sorted_arr.append(nums2[j])
                j += 1
        
        sorted_arr.extend(nums1[i:])
        sorted_arr.extend(nums2[j:])
        return sorted_arr

# Example usage:
sol = Solution()
print(sol.findMedianSortedArrays([1, 3], [2]))    # Output: 2.0
print(sol.findMedianSortedArrays([1, 2], [3, 4])) # Output: 2.5
# Out:
# 2.0
# 2.5

# %%
class Solution:
    def findMedianSortedArrays(self, nums1, nums2):
        
        if len(nums1) > len(nums2):
            nums1, nums2 = nums2, nums1
            
        m, n = len(nums1), len(nums2)
        low, high = 0, m
        
        while low <= high:
            
            partition1 = (low + high) // 2
            
            partition2 = (m + n + 1) // 2 - partition1
            
            # Boundary values (use infinity if partition is at the very ends)
            maxLeft1 = float('-inf') if partition1 == 0 else nums1[partition1 - 1]
            minRight1 = float('inf') if partition1 == m else nums1[partition1]
            
            maxLeft2 = float('-inf') if partition2 == 0 else nums2[partition2 - 1]
            minRight2 = float('inf') if partition2 == n else nums2[partition2]
            
            # Check if we found the correct partition
            if maxLeft1 <= minRight2 and maxLeft2 <= minRight1:
                # If total length is odd
                if (m + n) % 2 != 0:
                    return float(max(maxLeft1, maxLeft2))
                # If total length is even
                else:
                    return (max(maxLeft1, maxLeft2) + min(minRight1, minRight2)) / 2.0
            
            elif maxLeft1 > minRight2:
                # We are too far right in nums1, move left
                high = partition1 - 1
            else:
                # We are too far left in nums1, move right
                low = partition1 + 1

# %%
class Solution:
    def findMedianSortedArrays(self, nums1, nums2) -> float:
        # 1. Always binary search on the SHORTER ar.
        if len(nums1) > len(nums2):
            nums1, nums2 = nums2, nums1
            
        m, n = len(nums1), len(nums2)
        low, high = 0, m
        
        while low <= high:
            partition1 = (low + high) // 2
            partition2 = (m + n + 1) // 2 - partition1
            
            # Using -inf and inf to handle the "edge" cases you asked about
            maxLeft1 = float('-inf') if partition1 == 0 else nums1[partition1 - 1]
            minRight1 = float('inf') if partition1 == m else nums1[partition1]
            
            maxLeft2 = float('-inf') if partition2 == 0 else nums2[partition2 - 1]
            minRight2 = float('inf') if partition2 == n else nums2[partition2]
            
            if maxLeft1 <= minRight2 and maxLeft2 <= minRight1:
                # We found the perfect split!
                if (m + n) % 2 != 0:
                    return float(max(maxLeft1, maxLeft2))
                else:
                    return (max(maxLeft1, maxLeft2) + min(minRight1, minRight2)) / 2.0
            
            elif maxLeft1 > minRight2:
                # Too far right in nums1, move left
                high = partition1 - 1
            else:
                # Too far left in nums1, move right
                low = partition1 + 1
