# %%
stack = []
stack.append(10)
stack.append(11)
stack.append(9)
stack.append(4)
top= stack.pop()
top = stack.push(3)

print(stack[-1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 7
#       5 stack.append(4)
#       6 top= stack.pop()
# ----> 7 top = stack.push(3)
#       9 print(stack[-1])
#
# AttributeError: 'list' object has no attribute 'push'

# %% [raw]
# //
# #include <stdio.h>
# #include <stdlib.h>
# #incldue <stdbool.h>
#
# typedef struck
# {
#     int *collection; // pointer to a dynamically allocatoed ared
#     int capacity; // is
#     int size;
# } stuck;
# stack *create_stack(int capacity);
#
# int main()
# {
#
# return 0;
# }

# %% [raw]
# #include <stdio.h>
# #include <stdlib.h>
# #include <string.h>
# int stack[256];
# int count =0 ;
# void push(int x){
#     stack [count]=x;
#     count ++;
#
# }
#
# int pop (){
#
#     int res = stack[count-1];
#     count--;
#     return res
#
# }
#
#
# int main
# {
#     push(1);
#     push(2);
#     push(4);
#     push(8);
#     int i;
#
#     for(i=0;i <=4, i ++){
#     printf("%d", pop())
#     }
# }

# %%
# space 1 

a=[1,2,3,4,5,6] # array of values 
def bsort(arr):
    n = len (arr)
    flag = True
    while flag :
        flag =False 
        for i in range(1,n):
            if arr[i-1]>arr[i]:
                flag = True
                arr[i-1],arr[i] = arr[i], arr[i-1]
bsort(a)
a
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# Optimized Python program for implementation of Bubble Sort
def bubbleSort(arr):
    n = len(arr)
    
    # Traverse through all array elements
    for i in range(n):
        swapped = False

        # Last i elements are already in place
        for j in range(0, n-i-1):

            # Traverse the array from 0 to n-i-1
            # Swap if the element found is greater
            # than the next element
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
                swapped = True
        if (swapped == False):
            break

if __name__ == "__main__":
    arr = [5, 6, 1, 3,8,5,2,9]

    bubbleSort(arr)
    for i in range(len(arr)):
        print("%d" % arr[i], end=" ")
# Out:
# 1 2 3 5 5 6 8 9

# %%
b =[-5,3,2,1,-3,-4,7,2,2,3,8,19,11,6]
def insertion_sort(arr):
    n= len(b)
    for i in range (1,n):
        for j in range (i,0,-1):
            if arr[j-i]> arr[j]:
                arr[j--1],arr[i] = arr[i], arr[j-1]
            else:
                break
insertion_sort(b)

# %%
b
# Out:
# [-5, 3, 2, 1, -3, -4, 7, 2, 2, 3, 8, 19, 11, 6]

# %%
#  selection 
c= [-5,3,2,1,-3,-4,7,2,2,3,8,19,11,6]
def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_index=i 
        for j in range (i+1,n):
            if arr[j]<arr[min_index]:
                #if true this now means that the minimun index is now j
                min_index=j
                arr[i],arr[min_index]=arr[min_index], arr[i] 

selection_sort(c)
c
# Out:
# [-5, -4, -3, 1, 2, 2, 2, 3, 3, 6, 7, 8, 11, 19]
